# %% [markdown]
# <a href="https://colab.research.google.com/github/raza-manekia/Basics_Of_Pandas/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #INTRODUCTION AND SOME USEFUL COMMANDS OF PANDAS

# %%
import pandas as pd

data = pd.read_csv('/content/sample_data/california_housing_test.csv')
data
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 0         1537.0       606.0         6.6085            344700.0
# 1          809.0       277.0         3.5990            176500.0
# 2         1484.0       495.0         5.7934            270500.0
# 3           49.0        11.0         6.1359            330000.0
# 4          850.0       237.0         2.9375             81700.0
# ...          ...         ...            ...                 ...
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0
#
# [3000 rows x 9 columns]

# %% [markdown]
# Print starting and ending Values using **.head(n)** and **.tail(n)**

# %%
data.head(2)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0

# %%
data.tail(2)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0

# %% [markdown]
# Basic Info using **.info** and **.shape**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %%
data.shape
# Out:
# (3000, 9)

# %% [markdown]
# Working On **Columns**

# %%
data.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
data.rename(columns={'longitude':'length','latitude':'width', 'housing_median_age':'median', 'total_rooms':'Total'})
# Out:
#       length  width  median   Total  total_bedrooms  population  households  \
# 0    -122.05  37.37    27.0  3885.0           661.0      1537.0       606.0
# 1    -118.30  34.26    43.0  1510.0           310.0       809.0       277.0
# 2    -117.81  33.78    27.0  3589.0           507.0      1484.0       495.0
# 3    -118.36  33.82    28.0    67.0            15.0        49.0        11.0
# 4    -119.67  36.33    19.0  1241.0           244.0       850.0       237.0
# ...      ...    ...     ...     ...             ...         ...         ...
# 2995 -119.86  34.42    23.0  1450.0           642.0      1258.0       607.0
# 2996 -118.14  34.06    27.0  5257.0          1082.0      3496.0      1036.0
# 2997 -119.70  36.30    10.0   956.0           201.0       693.0       220.0
# 2998 -117.12  34.10    40.0    96.0            14.0        46.0        14.0
# 2999 -119.63  34.42    42.0  1765.0           263.0       753.0       260.0
#
#       median_income  median_house_value
# 0            6.6085            344700.0
# 1            3.5990            176500.0
# 2            5.7934            270500.0
# 3            6.1359            330000.0
# 4            2.9375             81700.0
# ...             ...                 ...
# 2995         1.1790            225000.0
# 2996         3.3906            237200.0
# 2997         2.2895             62000.0
# 2998         3.2708            162500.0
# 2999         8.5608            500001.0
#
# [3000 rows x 9 columns]

# %% [markdown]
# Statistical Analysis (**sum,mean,describe**)

# %%
data.sum()
# Out:
# longitude            -3.587676e+05
# latitude              1.069062e+05
# housing_median_age    8.653600e+04
# total_rooms           7.798736e+06
# total_bedrooms        1.589852e+06
# population            4.208396e+06
# households            1.469736e+06
# median_income         1.142182e+04
# median_house_value    6.175388e+08
# dtype: float64

# %% [markdown]
# **.sum(n)** where *n=0,1*
# n = 0: Coloumn wise sum
# n = 1: Row wise sum

# %%
data.sum(0)
# Out:
# longitude            -3.587676e+05
# latitude              1.069062e+05
# housing_median_age    8.653600e+04
# total_rooms           7.798736e+06
# total_bedrooms        1.589852e+06
# population            4.208396e+06
# households            1.469736e+06
# median_income         1.142182e+04
# median_house_value    6.175388e+08
# dtype: float64

# %%
data.mean()
# Out:
# longitude               -119.589200
# latitude                  35.635390
# housing_median_age        28.845333
# total_rooms             2599.578667
# total_bedrooms           529.950667
# population              1402.798667
# households               489.912000
# median_income              3.807272
# median_house_value    205846.275000
# dtype: float64

# %%
data.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# 25%        291.000000    780.000000   273.00000       2.544000
# 50%        437.000000   1155.000000   409.50000       3.487150
# 75%        636.000000   1742.750000   597.25000       4.656475
# max       5419.000000  11935.000000  4930.00000      15.000100
#
#        median_house_value
# count          3000.00000
# mean         205846.27500
# std          113119.68747
# min           22500.00000
# 25%          121200.00000
# 50%          177650.00000
# 75%          263975.00000
# max          500001.00000

# %% [markdown]
# locating your desired Item (**.loc(item)**)

# %%
data.loc[5]
# Out:
# longitude              -119.5600
# latitude                 36.5100
# housing_median_age       37.0000
# total_rooms            1018.0000
# total_bedrooms          213.0000
# population              663.0000
# households              204.0000
# median_income             1.6635
# median_house_value    67000.0000
# Name: 5, dtype: float64
